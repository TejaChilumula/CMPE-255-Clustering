# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt

# %%
newsgroups_data = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

# %%
plt.hist(km.labels_, bins=num_clusters, edgecolor='black')
plt.title('Cluster Size Distribution')
plt.xlabel('Cluster')
plt.ylabel('Number of Documents')
plt.show()

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(newsgroups_data)

# Clustering using K-Means
num_clusters = 3  # Change this number to set the number of clusters
km = KMeans(n_clusters=num_clusters, random_state=42)
km.fit(tfidf_matrix)

# Get cluster labels
cluster_labels = km.predict(tfidf_matrix)

# Visualizations
# 1. Cluster Size Distribution
plt.hist(cluster_labels, bins=num_clusters, edgecolor='black')
plt.title('Cluster Size Distribution')
plt.xlabel('Cluster')
plt.ylabel('Number of Documents')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-66bb7371e368> in <cell line: 2>()
#       1 vectorizer = TfidfVectorizer()
# ----> 2 tfidf_matrix = vectorizer.fit_transform(newsgroups_data)
#       3
#       4 # Clustering using K-Means
#       5 num_clusters = 3  # Change this number to set the number of clusters
#
# NameError: name 'newsgroups_data' is not defined
